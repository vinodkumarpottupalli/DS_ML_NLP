# %% [markdown]
# Importing important libraries

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.datasets import load_breast_cancer

# %%
X,y = load_breast_cancer(return_X_y = True)

# %% [markdown]
# Converting data to appropriate pytorch tensors

# %%
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

# %% [markdown]
# Designing the Neural network model
# 1. The model expects rows of data with 30 features (the first argument at the first layer set to 30)
# 2. The first hidden layer has 40 neurons, followed by a ReLU activation function
# 3. The second hidden layer has 10 neurons, followed by another ReLU activation function
# 4. The output layer has one neuron, followed by a sigmoid activation function

# %%
model = nn.Sequential(
    nn.Linear(30, 40),
    nn.ReLU(),
    nn.Linear(40, 10),
    nn.ReLU(),
    nn.Linear(10, 1),
    nn.Sigmoid())

# %% [markdown]
# Printing the model

# %%
print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=30, out_features=40, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=40, out_features=10, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=10, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %%
loss_fn = nn.BCELoss()  # binary cross entropy
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# Training the model with data

# %%
n_epochs = 100
batch_size = 20

for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        y_pred = model(Xbatch)
        ybatch = y[i:i+batch_size]
        loss = loss_fn(y_pred, ybatch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Finished epoch {epoch}, latest loss {loss}')
# Out:
# Finished epoch 0, latest loss 0.7894026041030884
# Finished epoch 1, latest loss 0.37662407755851746
# Finished epoch 2, latest loss 0.33444616198539734
# Finished epoch 3, latest loss 0.4222792983055115
# Finished epoch 4, latest loss 0.563845694065094
# Finished epoch 5, latest loss 0.5378807187080383
# Finished epoch 6, latest loss 0.4669705033302307
# Finished epoch 7, latest loss 0.4439091682434082
# Finished epoch 8, latest loss 0.4391575753688812
# Finished epoch 9, latest loss 0.43274760246276855
# Finished epoch 10, latest loss 0.42381036281585693
# Finished epoch 11, latest loss 0.42051708698272705
# Finished epoch 12, latest loss 0.4171067476272583
# Finished epoch 13, latest loss 0.41004687547683716
# Finished epoch 14, latest loss 0.4048377573490143
# Finished epoch 15, latest loss 0.39853692054748535
# Finished epoch 16, latest loss 0.39342859387397766
# Finished epoch 17, latest loss 0.3878503143787384
# Finished epoch 18, latest loss 0.3806278705596924
# Finished epoch 19, latest loss 0.3762277364730835
# Finished epoch 20, latest loss 0.3682052791118622
# Finished epoch 21, latest loss 0.3652538061141968
# Finished epoch 22, latest loss 0.35953348875045776
# Finished epoch 23, latest loss 0.35634011030197144
# Finished epoch 24, latest loss 0.35173654556274414
# Finished epoch 25, latest loss 0.3439255952835083
# Finished epoch 26, latest loss 0.34188535809516907
# Finished epoch 27, latest loss 0.3361547589302063
# Finished epoch 28, latest loss 0.33210432529449463
# Finished epoch 29, latest loss 0.32830315828323364
# Finished epoch 30, latest loss 0.32230982184410095
# Finished epoch 31, latest loss 0.3202242851257324
# Finished epoch 32, latest loss 0.3144301176071167
# Finished epoch 33, latest loss 0.30954787135124207
# Finished epoch 34, latest loss 0.30408453941345215
# Finished epoch 35, latest loss 0.3015180230140686
# Finished epoch 36, latest loss 0.29650288820266724
# Finished epoch 37, latest loss 0.2935888469219208
# Finished epoch 38, latest loss 0.28682249784469604
# Finished epoch 39, latest loss 0.2856593728065491
# Finished epoch 40, latest loss 0.27888965606689453
# Finished epoch 41, latest loss 0.2743004560470581
# Finished epoch 42, latest loss 0.27093735337257385
# Finished epoch 43, latest loss 0.324553906917572
# Finished epoch 44, latest loss 0.26525792479515076
# Finished epoch 45, latest loss 0.25309625267982483
# Finished epoch 46, latest loss 0.25262677669525146
# Finished epoch 47, latest loss 0.24735291302204132
# Finished epoch 48, latest loss 0.3062971234321594
# Finished epoch 49, latest loss 0.24296389520168304
# Finished epoch 50, latest loss 0.22846978902816772
# Finished epoch 51, latest loss 0.2304549217224121
# Finished epoch 52, latest loss 0.22294381260871887
# Finished epoch 53, latest loss 0.2935621738433838
# Finished epoch 54, latest loss 0.2092694789171219
# Finished epoch 55, latest loss 0.20781555771827698
# Finished epoch 56, latest loss 0.25912603735923767
# Finished epoch 57, latest loss 0.20993110537528992
# Finished epoch 58, latest loss 0.19316570460796356
# Finished epoch 59, latest loss 0.1960841417312622
# Finished epoch 60, latest loss 0.19294589757919312
# Finished epoch 61, latest loss 0.18818089365959167
# Finished epoch 62, latest loss 0.1790301352739334
# Finished epoch 63, latest loss 0.17363448441028595
# Finished epoch 64, latest loss 0.16976654529571533
# Finished epoch 65, latest loss 0.18423013389110565
# Finished epoch 66, latest loss 0.16818149387836456
# Finished epoch 67, latest loss 0.16451755166053772
# Finished epoch 68, latest loss 0.16090454161167145
# Finished epoch 69, latest loss 0.15555350482463837
# Finished epoch 70, latest loss 0.15139316022396088
# Finished epoch 71, latest loss 0.14955946803092957
# Finished epoch 72, latest loss 0.14361485838890076
# Finished epoch 73, latest loss 0.1955776810646057
# Finished epoch 74, latest loss 0.14317098259925842
# Finished epoch 75, latest loss 0.13400541245937347
# Finished epoch 76, latest loss 0.1320137232542038
# Finished epoch 77, latest loss 0.13094733655452728
# Finished epoch 78, latest loss 0.12449029833078384
# Finished epoch 79, latest loss 0.12328486889600754
# Finished epoch 80, latest loss 0.11902233213186264
# Finished epoch 81, latest loss 0.11696341633796692
# Finished epoch 82, latest loss 0.11202175170183182
# Finished epoch 83, latest loss 0.1106647327542305
# Finished epoch 84, latest loss 0.1537010669708252
# Finished epoch 85, latest loss 0.11132677644491196
# Finished epoch 86, latest loss 0.10555869340896606
# Finished epoch 87, latest loss 0.10340578854084015
# Finished epoch 88, latest loss 0.09966221451759338
# Finished epoch 89, latest loss 0.09489157795906067
# Finished epoch 90, latest loss 0.09360179305076599
# Finished epoch 91, latest loss 0.09150318056344986
# Finished epoch 92, latest loss 0.08835650980472565
# Finished epoch 93, latest loss 0.12495366483926773
# Finished epoch 94, latest loss 0.09281545132398605
# Finished epoch 95, latest loss 0.08039253205060959
# Finished epoch 96, latest loss 0.07821451127529144
# Finished epoch 97, latest loss 0.07648525387048721
# Finished epoch 98, latest loss 0.07587376981973648
# Finished epoch 99, latest loss 0.07155277580022812

# %%
predictions = model(X)
# round predictions
rounded = predictions.round()
predictions = (model(X) > 0.5).int()
for i in range(30):
    print('For point %d : Predicted  %d (expected %d)' % (i, predictions[i], y[i]))
# Out:
# For point 0 : Predicted  0 (expected 0)
# For point 1 : Predicted  0 (expected 0)
# For point 2 : Predicted  0 (expected 0)
# For point 3 : Predicted  1 (expected 0)
# For point 4 : Predicted  0 (expected 0)
# For point 5 : Predicted  0 (expected 0)
# For point 6 : Predicted  0 (expected 0)
# For point 7 : Predicted  0 (expected 0)
# For point 8 : Predicted  1 (expected 0)
# For point 9 : Predicted  0 (expected 0)
# For point 10 : Predicted  0 (expected 0)
# For point 11 : Predicted  0 (expected 0)
# For point 12 : Predicted  0 (expected 0)
# For point 13 : Predicted  1 (expected 0)
# For point 14 : Predicted  1 (expected 0)
# For point 15 : Predicted  0 (expected 0)
# For point 16 : Predicted  0 (expected 0)
# For point 17 : Predicted  0 (expected 0)
# For point 18 : Predicted  0 (expected 0)
# For point 19 : Predicted  1 (expected 1)
# For point 20 : Predicted  1 (expected 1)
# For point 21 : Predicted  1 (expected 1)
# For point 22 : Predicted  0 (expected 0)
# For point 23 : Predicted  0 (expected 0)
# For point 24 : Predicted  0 (expected 0)
# For point 25 : Predicted  0 (expected 0)
# For point 26 : Predicted  0 (expected 0)
# For point 27 : Predicted  0 (expected 0)
# For point 28 : Predicted  0 (expected 0)
# For point 29 : Predicted  0 (expected 0)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
accuracy = print('Accuracy score of the  model is ',accuracy_score(y, predictions))
print('F1 Score of the model is ',f1_score(y, predictions))
confusion_matrix(y, predictions, labels = [1, 0])
# Out:
# Accuracy score of the  model is  0.929701230228471
# F1 Score of the model is  0.9466666666666667
# array([[355,   2],
#        [ 38, 174]])
