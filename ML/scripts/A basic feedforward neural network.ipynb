# %% [markdown]
# Importing important libraries

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.datasets import load_breast_cancer

# %%
X,y = load_breast_cancer(return_X_y = True)

# %% [markdown]
# Converting data to appropriate pytorch tensors

# %%
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

# %% [markdown]
# Designing the Neural network model
# 1. The model expects rows of data with 30 features (the first argument at the first layer set to 30)
# 2. The first hidden layer has 40 neurons, followed by a ReLU activation function
# 3. The second hidden layer has 10 neurons, followed by another ReLU activation function
# 4. The output layer has one neuron, followed by a sigmoid activation function

# %%
model = nn.Sequential(
    nn.Linear(30, 40),
    nn.ReLU(),
    nn.Linear(40, 10),
    nn.ReLU(),
    nn.Linear(10, 1),
    nn.Sigmoid())

# %% [markdown]
# Printing the model

# %%
print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=30, out_features=40, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=40, out_features=10, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=10, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %%
loss_fn = nn.BCELoss()  # binary cross entropy
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# Training the model with data

# %%
n_epochs = 100
batch_size = 20

for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        y_pred = model(Xbatch)
        ybatch = y[i:i+batch_size]
        loss = loss_fn(y_pred, ybatch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Finished epoch {epoch}, latest loss {loss}')
# Out:
# Finished epoch 0, latest loss 66.66666412353516
# Finished epoch 1, latest loss 66.66666412353516
# Finished epoch 2, latest loss 66.66666412353516
# Finished epoch 3, latest loss 66.66666412353516
# Finished epoch 4, latest loss 66.66666412353516
# Finished epoch 5, latest loss 66.66666412353516
# Finished epoch 6, latest loss 66.66666412353516
# Finished epoch 7, latest loss 66.66666412353516
# Finished epoch 8, latest loss 66.66666412353516
# Finished epoch 9, latest loss 66.66666412353516
# Finished epoch 10, latest loss 66.66666412353516
# Finished epoch 11, latest loss 66.66666412353516
# Finished epoch 12, latest loss 66.66666412353516
# Finished epoch 13, latest loss 66.66666412353516
# Finished epoch 14, latest loss 66.66666412353516
# Finished epoch 15, latest loss 66.66666412353516
# Finished epoch 16, latest loss 66.66666412353516
# Finished epoch 17, latest loss 66.66666412353516
# Finished epoch 18, latest loss 66.66666412353516
# Finished epoch 19, latest loss 66.66666412353516
# Finished epoch 20, latest loss 66.66666412353516
# Finished epoch 21, latest loss 66.66666412353516
# Finished epoch 22, latest loss 66.66666412353516
# Finished epoch 23, latest loss 66.66666412353516
# Finished epoch 24, latest loss 66.66666412353516
# Finished epoch 25, latest loss 66.66666412353516
# Finished epoch 26, latest loss 66.66666412353516
# Finished epoch 27, latest loss 66.66666412353516
# Finished epoch 28, latest loss 66.66666412353516
# Finished epoch 29, latest loss 66.66666412353516
# Finished epoch 30, latest loss 66.66666412353516
# Finished epoch 31, latest loss 66.66666412353516
# Finished epoch 32, latest loss 66.66666412353516
# Finished epoch 33, latest loss 66.66666412353516
# Finished epoch 34, latest loss 66.66666412353516
# Finished epoch 35, latest loss 66.66666412353516
# Finished epoch 36, latest loss 66.66666412353516
# Finished epoch 37, latest loss 66.66666412353516
# Finished epoch 38, latest loss 66.66666412353516
# Finished epoch 39, latest loss 66.66666412353516
# Finished epoch 40, latest loss 66.66666412353516
# Finished epoch 41, latest loss 66.66666412353516
# Finished epoch 42, latest loss 66.66666412353516
# Finished epoch 43, latest loss 66.66666412353516
# Finished epoch 44, latest loss 66.66666412353516
# Finished epoch 45, latest loss 66.66666412353516
# Finished epoch 46, latest loss 66.66666412353516
# Finished epoch 47, latest loss 66.66666412353516
# Finished epoch 48, latest loss 66.66666412353516
# Finished epoch 49, latest loss 66.66666412353516
# Finished epoch 50, latest loss 66.66666412353516
# Finished epoch 51, latest loss 66.66666412353516
# Finished epoch 52, latest loss 66.66666412353516
# Finished epoch 53, latest loss 66.66666412353516
# Finished epoch 54, latest loss 66.66666412353516
# Finished epoch 55, latest loss 66.66666412353516
# Finished epoch 56, latest loss 66.66666412353516
# Finished epoch 57, latest loss 66.66666412353516
# Finished epoch 58, latest loss 66.66666412353516
# Finished epoch 59, latest loss 66.66666412353516
# Finished epoch 60, latest loss 66.66666412353516
# Finished epoch 61, latest loss 66.66666412353516
# Finished epoch 62, latest loss 66.66666412353516
# Finished epoch 63, latest loss 66.66666412353516
# Finished epoch 64, latest loss 66.66666412353516
# Finished epoch 65, latest loss 66.66666412353516
# Finished epoch 66, latest loss 66.66666412353516
# Finished epoch 67, latest loss 66.66666412353516
# Finished epoch 68, latest loss 66.66666412353516
# Finished epoch 69, latest loss 66.66666412353516
# Finished epoch 70, latest loss 66.66666412353516
# Finished epoch 71, latest loss 66.66666412353516
# Finished epoch 72, latest loss 66.66666412353516
# Finished epoch 73, latest loss 66.66666412353516
# Finished epoch 74, latest loss 66.66666412353516
# Finished epoch 75, latest loss 66.66666412353516
# Finished epoch 76, latest loss 66.66666412353516
# Finished epoch 77, latest loss 66.66666412353516
# Finished epoch 78, latest loss 66.66666412353516
# Finished epoch 79, latest loss 66.66666412353516
# Finished epoch 80, latest loss 66.66666412353516
# Finished epoch 81, latest loss 66.66666412353516
# Finished epoch 82, latest loss 66.66666412353516
# Finished epoch 83, latest loss 66.66666412353516
# Finished epoch 84, latest loss 66.66666412353516
# Finished epoch 85, latest loss 66.66666412353516
# Finished epoch 86, latest loss 66.66666412353516
# Finished epoch 87, latest loss 66.66666412353516
# Finished epoch 88, latest loss 66.66666412353516
# Finished epoch 89, latest loss 66.66666412353516
# Finished epoch 90, latest loss 66.66666412353516
# Finished epoch 91, latest loss 66.66666412353516
# Finished epoch 92, latest loss 66.66666412353516
# Finished epoch 93, latest loss 66.66666412353516
# Finished epoch 94, latest loss 66.66666412353516
# Finished epoch 95, latest loss 66.66666412353516
# Finished epoch 96, latest loss 66.66666412353516
# Finished epoch 97, latest loss 66.66666412353516
# Finished epoch 98, latest loss 66.66666412353516
# Finished epoch 99, latest loss 66.66666412353516

# %%
predictions = model(X)
# round predictions
rounded = predictions.round()
predictions = (model(X) > 0.5).int()
for i in range(30):
    print('For point %d : Predicted  %d (expected %d)' % (i, predictions[i], y[i]))
# Out:
# For point 0 : Predicted  1 (expected 0)
# For point 1 : Predicted  1 (expected 0)
# For point 2 : Predicted  1 (expected 0)
# For point 3 : Predicted  1 (expected 0)
# For point 4 : Predicted  1 (expected 0)
# For point 5 : Predicted  1 (expected 0)
# For point 6 : Predicted  1 (expected 0)
# For point 7 : Predicted  1 (expected 0)
# For point 8 : Predicted  1 (expected 0)
# For point 9 : Predicted  1 (expected 0)
# For point 10 : Predicted  1 (expected 0)
# For point 11 : Predicted  1 (expected 0)
# For point 12 : Predicted  1 (expected 0)
# For point 13 : Predicted  1 (expected 0)
# For point 14 : Predicted  1 (expected 0)
# For point 15 : Predicted  1 (expected 0)
# For point 16 : Predicted  1 (expected 0)
# For point 17 : Predicted  1 (expected 0)
# For point 18 : Predicted  1 (expected 0)
# For point 19 : Predicted  1 (expected 1)
# For point 20 : Predicted  1 (expected 1)
# For point 21 : Predicted  1 (expected 1)
# For point 22 : Predicted  1 (expected 0)
# For point 23 : Predicted  1 (expected 0)
# For point 24 : Predicted  1 (expected 0)
# For point 25 : Predicted  1 (expected 0)
# For point 26 : Predicted  1 (expected 0)
# For point 27 : Predicted  1 (expected 0)
# For point 28 : Predicted  1 (expected 0)
# For point 29 : Predicted  1 (expected 0)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
accuracy = print('Accuracy score of the  model is ',accuracy_score(y, predictions))
print('F1 Score of the model is ',f1_score(y, predictions))
confusion_matrix(y, predictions, labels = [1, 0])
# Out:
# Accuracy score of the  model is  0.6274165202108963
# F1 Score of the model is  0.7710583153347732
# array([[357,   0],
#        [212,   0]])
